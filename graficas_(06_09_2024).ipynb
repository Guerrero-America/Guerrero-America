# %% [markdown]
# <a href="https://colab.research.google.com/github/Guerrero-America/MetodosNumericos/blob/main/graficas_(06_09_2024).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gráfica de $f(x)=x - 3^{-x}$

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Función cuadrática.
def f(x):
    return x + 3**(-x)

def g(x):
    return x

def h(x):
    return -3**(-x)

# %%
f(-5)
# Out:
# -248

# %%
# Valores del eje X que toma el gráfico.
x=np.linspace(-10, 10,100)

# %%
plt.figure(figsize=(10,10))
# Graficar ambas funciones.
plt.plot(x, f(x), color="green")
plt.plot(x, g(x), color="orange")
#plt.legend({'g(x)= x'})
plt.legend({'h(x)= x','g(x)= -3**(-x)'})
#plt.plot(x, h(x))
#Caracteristicas de la grafica
plt.title("Gráfica $f(x)=x-3**(-x)$")
plt.axhline(0, color="grey")
plt.axvline(0, color="grey")
plt.xlabel("Eje x")
plt.ylabel("Eje y")

plt.xlim(-5, 5)
plt.ylim(-5, 5)
#plt.savefig("output.png") # Guardar gráfico como imágen PNG.
plt.grid(color="pink")
# Mostrarlo.
plt.show()

# %% [markdown]
# Ejercicio 1: Graficar las funciones $x$ y $3^{-x}$ en una sola figura y comentar cómo su resta da origen a la gráfica de $f(x)$.
#
# Ejercicio 2: Agregar título, color, retícula, rótulos a los ejes y aumentar el tamaño de la gráfica.
